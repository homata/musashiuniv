# %% [markdown]
# # 地理空間データの操作
#
# ## Geometricオブジェクト

# %%
from shapely.geometry import Point

Point(1, 1)
# or
Point([1, 1])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from shapely.geometry import Point
#       2
#       3 Point(1, 1)
#       4 # or
#
# ModuleNotFoundError: No module named 'shapely'

# %%
tokyo = Point(139.766667, 35.681111)
shinjuku = Point(139.700278, 35.690833)
shinagawa = Point(139.738694, 35.628222)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 tokyo = Point(139.766667, 35.681111)
#       2 shinjuku = Point(139.700278, 35.690833)
#       3 shinagawa = Point(139.738694, 35.628222)
#
# NameError: name 'Point' is not defined

# %%
from shapely.geometry import LineString

tokyo_shinjuku = LineString(
    [
        (139.766667, 35.681111),
        (139.700278, 35.690833),
    ]
)
tokyo_shinjuku
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from shapely.geometry import LineString
#       2
#       3 tokyo_shinjuku = LineString(
#       4     [
#
# ModuleNotFoundError: No module named 'shapely'

# %%
from shapely.geometry import Polygon

tokyo_shinjuku_shinagawa = Polygon(
    [
        (139.766667, 35.681111),
        (139.700278, 35.690833),
        (139.738694, 35.628222),
    ]
)
tokyo_shinjuku_shinagawa
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from shapely.geometry import Polygon
#       2
#       3 tokyo_shinjuku_shinagawa = Polygon(
#       4     [
#
# ModuleNotFoundError: No module named 'shapely'

# %% [markdown]
# ## Geometricオブジェクトの属性

# %%
tokyo.geom_type
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 tokyo.geom_type
#
# NameError: name 'tokyo' is not defined

# %%
tokyo_shinjuku.geom_type
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 tokyo_shinjuku.geom_type
#
# NameError: name 'tokyo_shinjuku' is not defined

# %%
tokyo_shinjuku_shinagawa.geom_type
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tokyo_shinjuku_shinagawa.geom_type
#
# NameError: name 'tokyo_shinjuku_shinagawa' is not defined

# %%
tokyo_shinjuku.xy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 tokyo_shinjuku.xy
#
# NameError: name 'tokyo_shinjuku' is not defined

# %%
list(tokyo_shinjuku.coords)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 list(tokyo_shinjuku.coords)
#
# NameError: name 'tokyo_shinjuku' is not defined

# %%
tokyo_shinjuku.coords[:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 tokyo_shinjuku.coords[:]
#
# NameError: name 'tokyo_shinjuku' is not defined

# %%
tokyo_shinjuku.length
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 tokyo_shinjuku.length
#
# NameError: name 'tokyo_shinjuku' is not defined

# %%
tokyo_shinjuku_shinagawa.length
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 tokyo_shinjuku_shinagawa.length
#
# NameError: name 'tokyo_shinjuku_shinagawa' is not defined

# %%
tokyo_shinjuku_shinagawa.area
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 tokyo_shinjuku_shinagawa.area
#
# NameError: name 'tokyo_shinjuku_shinagawa' is not defined

# %%
tokyo_shinjuku.bounds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 tokyo_shinjuku.bounds
#
# NameError: name 'tokyo_shinjuku' is not defined

# %%
tokyo_shinjuku_shinagawa.bounds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 tokyo_shinjuku_shinagawa.bounds
#
# NameError: name 'tokyo_shinjuku_shinagawa' is not defined

# %% [markdown]
# ## 距離の算出

# %%
tokyo.distance(shinjuku)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 tokyo.distance(shinjuku)
#
# NameError: name 'tokyo' is not defined

# %%
from geopy import distance

tokyo_shinjuku_distance = distance.geodesic(
    list(reversed(tokyo.coords[0])),
    list(reversed(shinjuku.coords[0])),
)
tokyo_shinjuku_distance
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from geopy import distance
#       2
#       3 tokyo_shinjuku_distance = distance.geodesic(
#       4     list(reversed(tokyo.coords[0])),
#
# ModuleNotFoundError: No module named 'geopy'

# %%
tokyo_shinjuku_distance.meters
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 tokyo_shinjuku_distance.meters
#
# NameError: name 'tokyo_shinjuku_distance' is not defined

# %%
tokyo_shinjuku_distance.km
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 tokyo_shinjuku_distance.km
#
# NameError: name 'tokyo_shinjuku_distance' is not defined
