# %% [markdown]
# # 地理空間データのファイル形式と読み込み

# %% [markdown]
# ## GeoJSON

# %%
from shapely import from_geojson

geojson = """{
    "type": "FeatureCollection",
    "features": [
        {
            "type": "Feature",
            "properties": {
                "name": "yurakucho"
            },
            "geometry": {
                "type": "Point",
                "coordinates": [
                    35.675056,
                    139.763333
                ]
            }
        },
        {
            "type": "Feature",
            "properties": {
                "name": "tokyo-kanda"
            },
            "geometry": {
                "type": "LineString",
                "coordinates": [
                    [
                        35.681111,
                        139.766667
                    ],
                    [
                        35.691667,
                        139.770833
                    ]
                ]
            }
        }
    ]
}"""
geo_collection = from_geojson(geojson)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from shapely import from_geojson
#       3 geojson = """{
#       4     "type": "FeatureCollection",
#       5     "features": [
#    (...)     38     ]
#      39 }"""
#      40 geo_collection = from_geojson(geojson)
#
# ModuleNotFoundError: No module named 'shapely'

# %%
type(geo_collection)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 type(geo_collection)
#
# NameError: name 'geo_collection' is not defined

# %%
from shapely import to_geojson

print(to_geojson(geo_collection, indent=4))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from shapely import to_geojson
#       3 print(to_geojson(geo_collection, indent=4))
#
# ModuleNotFoundError: No module named 'shapely'

# %%
from io import StringIO
import geopandas as gpd

geojson_gdf = gpd.read_file(StringIO(geojson))
geojson_gdf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 from io import StringIO
# ----> 2 import geopandas as gpd
#       4 geojson_gdf = gpd.read_file(StringIO(geojson))
#       5 geojson_gdf
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
type(geojson_gdf.loc[0, "geometry"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 type(geojson_gdf.loc[0, "geometry"])
#
# NameError: name 'geojson_gdf' is not defined

# %%
geojson_gdf.loc[0, "geometry"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 geojson_gdf.loc[0, "geometry"]
#
# NameError: name 'geojson_gdf' is not defined

# %%
type(geojson_gdf.loc[1, "geometry"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 type(geojson_gdf.loc[1, "geometry"])
#
# NameError: name 'geojson_gdf' is not defined

# %%
geojson_gdf.loc[1, "geometry"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 geojson_gdf.loc[1, "geometry"]
#
# NameError: name 'geojson_gdf' is not defined

# %%
print(geojson_gdf.to_json(indent=4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(geojson_gdf.to_json(indent=4))
#
# NameError: name 'geojson_gdf' is not defined

# %%
geojson_gdf.to_file(
    "./data/yurakucho-kanda.geojson",
    driver="GeoJSON",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 geojson_gdf.to_file(
#       2     "./data/yurakucho-kanda.geojson",
#       3     driver="GeoJSON",
#       4 )
#
# NameError: name 'geojson_gdf' is not defined

# %%
# 生成したファイルを削除
# !rm -f ./data/yurakucho-kanda.geojson

# %% [markdown]
# ## シェープファイル

# %%
shapefile_gdf = gpd.read_file("./data/yurakucho")
shapefile_gdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 shapefile_gdf = gpd.read_file("./data/yurakucho")
#       2 shapefile_gdf
#
# NameError: name 'gpd' is not defined

# %%
shapefile_gdf.to_file("./data/yurakucho")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 shapefile_gdf.to_file("./data/yurakucho")
#
# NameError: name 'shapefile_gdf' is not defined

# %% [markdown]
# ## GeoTIFF

# %%
import rasterio

dataset = rasterio.open("./data/L03-b-14_5236.tif")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import rasterio
#       3 dataset = rasterio.open("./data/L03-b-14_5236.tif")
#
# ModuleNotFoundError: No module named 'rasterio'

# %%
dataset.bounds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 dataset.bounds
#
# NameError: name 'dataset' is not defined

# %%
dataset.crs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 dataset.crs
#
# NameError: name 'dataset' is not defined

# %%
type(dataset.crs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 type(dataset.crs)
#
# NameError: name 'dataset' is not defined

# %%
dataset.indexes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 dataset.indexes
#
# NameError: name 'dataset' is not defined

# %%
dataset.read(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 dataset.read(1)
#
# NameError: name 'dataset' is not defined

# %%
from PIL import Image

Image.fromarray(dataset.read(1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 from PIL import Image
# ----> 3 Image.fromarray(dataset.read(1))
#
# NameError: name 'dataset' is not defined
