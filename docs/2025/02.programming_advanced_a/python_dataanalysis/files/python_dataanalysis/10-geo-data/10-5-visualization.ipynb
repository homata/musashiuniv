# %% [markdown]
# # 地理空間データの可視化

# %% [markdown]
# ## ポイントの可視化

# %%
import pandas as pd

itami_wifi = pd.read_csv("data/282073publicwirelesslan202204.csv")
itami_wifi.iloc[:3, 3:10]
# Out:
#            名称          名称_カナ                名称_英語              住所  方書  \
# 0      有岡城跡公園  アリオカジョウセキコウエン  Arioka Castle Ruins    兵庫県伊丹市伊丹1-16 NaN
# 1    市バス総合案内所  シバスソウゴウアンナイジョ    City Bus Terminal  兵庫県伊丹市西台1-1-24 NaN
# 2  市立伊丹ミュージアム   シリツイタミミュージアム    Itami City Museum    兵庫県伊丹市宮ノ前2-5 NaN
#
#           緯度          経度
# 0  34.780851  135.421042
# 1  34.780171  135.413086
# 2  34.781996  135.417263

# %%
itami_center = itami_wifi.loc[:, ["緯度", "経度"]].mean()
itami_center
# Out:
# 緯度     34.781261
# 経度    135.422682
# dtype: float64

# %%
import folium

itami_wifi_map = folium.Map(
    location=itami_center,
    zoom_start=15.2,
    width=800,
    height=400,
)
itami_wifi_map
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import folium
#       2
#       3 itami_wifi_map = folium.Map(
#       4     location=itami_center,
#
# ModuleNotFoundError: No module named 'folium'

# %%
marker = folium.Marker(location=itami_wifi.loc[0, ["緯度", "経度"]])
marker.add_to(itami_wifi_map)
itami_wifi_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 marker = folium.Marker(location=itami_wifi.loc[0, ["緯度", "経度"]])
#       2 marker.add_to(itami_wifi_map)
#       3 itami_wifi_map
#
# NameError: name 'folium' is not defined

# %%
itami_wifi.loc[:, ["緯度", "経度"]].apply(
    lambda x: folium.Marker(location=x).add_to(itami_wifi_map),
    axis=1,
)
itami_wifi_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 itami_wifi.loc[:, ["緯度", "経度"]].apply(
#       2     lambda x: folium.Marker(location=x).add_to(itami_wifi_map),
#       3     axis=1,
#       4 )
#
# File ~\workspace\musashiuniv\musashiuniv_manuscript\.venv\Lib\site-packages\pandas\core\frame.py:12437, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   12433                 engine_kwargs=engine_kwargs,
#   12434                 args=args,
#   12435                 kwargs=kwargs,
#   12436             )
# > 12437             return op.apply().__finalize__(self, method="apply")
#   12438         elif hasattr(engine, "__pandas_udf__"):
#   12439             if result_type is not None:
#   12440                 raise NotImplementedError(
#
# File ~\workspace\musashiuniv\musashiuniv_manuscript\.venv\Lib\site-packages\pandas\core\apply.py:1015, in FrameApply.apply(self)
#    1012 elif self.raw:
#    1013     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# -> 1015 return self.apply_standard()
#
# File ~\workspace\musashiuniv\musashiuniv_manuscript\.venv\Lib\site-packages\pandas\core\apply.py:1167, in FrameApply.apply_standard(self)
#    1165 def apply_standard(self):
#    1166     if self.engine == "python":
# -> 1167         results, res_index = self.apply_series_generator()
#    1168     else:
#    1169         results, res_index = self.apply_series_numba()
#
# File ~\workspace\musashiuniv\musashiuniv_manuscript\.venv\Lib\site-packages\pandas\core\apply.py:1183, in FrameApply.apply_series_generator(self)
#    1180 results = {}
#    1182 for i, v in enumerate(series_gen):
# -> 1183     results[i] = self.func(v, *self.args, **self.kwargs)
#    1184     if isinstance(results[i], ABCSeries):
#    1185         # If we have a view on v, we need to make a copy because
#    1186         #  series_generator will swap out the underlying data
#    1187         results[i] = results[i].copy(deep=False)
#
# Cell In[5], line 2, in <lambda>(x)
# ----> 2     lambda x: folium.Marker(location=x).add_to(itami_wifi_map),
#
# NameError: name 'folium' is not defined

# %%
import geopandas as gpd

land_price_gdf = (
    gpd.read_file(
        "https://nlftp.mlit.go.jp/ksj/gml/data/L01/L01-22/L01-22_25_GML.zip"
    )
    .groupby("L01_005")
    .get_group("2022")
)
land_price_gdf.loc[:3, ["L01_006", "L01_023", "geometry"]]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import geopandas as gpd
#       2
#       3 land_price_gdf = (
#       4     gpd.read_file(
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
land_price = land_price_gdf.apply(
    lambda s: pd.Series(
        (
            s["geometry"].y,
            s["geometry"].x,
            s["L01_006"],
        )
    ),
    axis=1,
).values
land_price[:3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 land_price = land_price_gdf.apply(
#       2     lambda s: pd.Series(
#       3         (
#       4             s["geometry"].y,
#
# NameError: name 'land_price_gdf' is not defined

# %%
from folium.plugins import HeatMap

shiga_center = (
    land_price_gdf.loc[:, "geometry"].y.mean(),
    land_price_gdf.loc[:, "geometry"].x.mean(),
)
land_price_map = folium.Map(
    location=shiga_center,
    zoom_start=10,
)
HeatMap(
    data=land_price,
    radius=12,
).add_to(land_price_map)
land_price_map
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from folium.plugins import HeatMap
#       2
#       3 shiga_center = (
#       4     land_price_gdf.loc[:, "geometry"].y.mean(),
#
# ModuleNotFoundError: No module named 'folium'

# %% [markdown]
# ## ラインの可視化

# %%
minx, miny = land_price_gdf.loc[:, "geometry"].bounds.min()[
    ["minx", "miny"]
]
maxx, maxy = land_price_gdf.loc[:, "geometry"].bounds.max()[
    ["maxx", "maxy"]
]
rail_gdf = gpd.read_file(
    "https://nlftp.mlit.go.jp/ksj/gml/data/N02/N02-21/N02-21_GML.zip"
).cx[minx:maxx, miny:maxy]
rail_gdf.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 minx, miny = land_price_gdf.loc[:, "geometry"].bounds.min()[
#       2     ["minx", "miny"]
#       3 ]
#       4 maxx, maxy = land_price_gdf.loc[:, "geometry"].bounds.max()[
#
# NameError: name 'land_price_gdf' is not defined

# %%
# 京津線のデータを抽出
keishinsen = rail_gdf.groupby("N02_003")["geometry"].get_group("京津線")
# 中心となる座標
keishinsen_center = (
    keishinsen.map(lambda p: p.centroid.y).mean(),
    keishinsen.map(lambda p: p.centroid.x).mean(),
)
keishinsen_center
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # 京津線のデータを抽出
# ----> 2 keishinsen = rail_gdf.groupby("N02_003")["geometry"].get_group("京津線")
#       3 # 中心となる座標
#       4 keishinsen_center = (
#       5     keishinsen.map(lambda p: p.centroid.y).mean(),
#
# NameError: name 'rail_gdf' is not defined

# %%
import numpy as np


keishinsen_map = folium.Map(
    location=keishinsen_center,
    zoom_start=14,
)
keishinsen.apply(
    lambda s: folium.PolyLine(
        # 緯度, 経度の順番に変換、fliplr関数で順序を反転
        locations=np.fliplr(s.coords),
        weight=15  # 線の太さ
    ).add_to(keishinsen_map)
)
keishinsen_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 import numpy as np
#       2
#       3
# ----> 4 keishinsen_map = folium.Map(
#       5     location=keishinsen_center,
#       6     zoom_start=14,
#       7 )
#
# NameError: name 'folium' is not defined

# %%
rail_map = folium.Map(
    location=shiga_center,
    zoom_start=10,
)
folium.features.GeoJson(rail_gdf).add_to(rail_map)
rail_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 rail_map = folium.Map(
#       2     location=shiga_center,
#       3     zoom_start=10,
#       4 )
#
# NameError: name 'folium' is not defined

# %% [markdown]
# ## ポリゴンの可視化

# %%
did_gdf = gpd.read_file("./data/A16-15_25_DID.geojson")
did_gdf.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 did_gdf = gpd.read_file("./data/A16-15_25_DID.geojson")
#       2 did_gdf.head()
#
# NameError: name 'gpd' is not defined

# %%
did_map = folium.Map(
    location=shiga_center,
    zoom_start=10,
)
folium.GeoJson(did_gdf).add_to(did_map)
did_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 did_map = folium.Map(
#       2     location=shiga_center,
#       3     zoom_start=10,
#       4 )
#
# NameError: name 'folium' is not defined

# %%
did_choroplethmap = folium.Map(
    location=shiga_center,
    zoom_start=10,
)
folium.features.Choropleth(
    geo_data=did_gdf,
    data=did_gdf,
    key_on="feature.properties.DIDid",
    columns=["DIDid", "人口"],
    legend_name="人口",
).add_to(did_choroplethmap)
did_choroplethmap
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 did_choroplethmap = folium.Map(
#       2     location=shiga_center,
#       3     zoom_start=10,
#       4 )
#
# NameError: name 'folium' is not defined
