# %% [markdown]
# # GeoPandas
#
# ## GeoDataFrame

# %%
import geopandas as gpd

gdf = gpd.read_file("./data/N03-20220101_25_GML/N03-22_25_220101.geojson")
gdf.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import geopandas as gpd
#       2
#       3 gdf = gpd.read_file("./data/N03-20220101_25_GML/N03-22_25_220101.geojson")
#       4 gdf.head()
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
gdf = gpd.read_file("./data/N03-20220101_25_GML/")
gdf.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 gdf = gpd.read_file("./data/N03-20220101_25_GML/")
#       2 gdf.head()
#
# NameError: name 'gpd' is not defined

# %% [markdown]
# ## .cxインデクサ

# %%
gdf.cx[136.2:136.4, 35.5:35.6]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 gdf.cx[136.2:136.4, 35.5:35.6]
#
# NameError: name 'gdf' is not defined

# %% [markdown]
# ## GeoSeriesの処理

# %%
gdf.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 gdf.dtypes
#
# NameError: name 'gdf' is not defined

# %%
geoseries = gdf.loc[:, "geometry"]
type(geoseries)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 geoseries = gdf.loc[:, "geometry"]
#       2 type(geoseries)
#
# NameError: name 'gdf' is not defined

# %%
type(geoseries[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 type(geoseries[0])
#
# NameError: name 'geoseries' is not defined

# %%
geoseries[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 geoseries[0]
#
# NameError: name 'geoseries' is not defined

# %%
geoseries[0].geom_type
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 geoseries[0].geom_type
#
# NameError: name 'geoseries' is not defined

# %%
geoseries.geom_type.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 geoseries.geom_type.head()
#
# NameError: name 'geoseries' is not defined

# %%
geoseries.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 geoseries.plot()
#
# NameError: name 'geoseries' is not defined

# %%
geoseries.length.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 geoseries.length.head(3)
#
# NameError: name 'geoseries' is not defined

# %%
geoseries_transformed = geoseries.to_crs("EPSG:6674")
geoseries_transformed.length.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 geoseries_transformed = geoseries.to_crs("EPSG:6674")
#       2 geoseries_transformed.length.head(3)
#
# NameError: name 'geoseries' is not defined

# %%
geoseries_transformed.area.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 geoseries_transformed.area.head(3)
#
# NameError: name 'geoseries_transformed' is not defined
