# %% [markdown]
# # 外れ値、異常値

# %% [markdown]
# ## 外れ値の確認

# %% [markdown]
# ### 箱ひげ図による外れ値の確認

# %%
import pandas as pd
import plotly.express as px

df = pd.read_parquet("data/penguins.parquet")
px.box(df, x="Species_short", y="Body_Mass")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 import plotly.express as px
#       3
#       4 df = pd.read_parquet("data/penguins.parquet")
#       5 px.box(df, x="Species_short", y="Body_Mass")
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# ### 分位点による外れ値の確認

# %%
df.groupby("Species_short")["Body_Mass"].quantile(
    q=[0, 0.01, 0.05, 0.95, 0.99, 1]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.groupby("Species_short")["Body_Mass"].quantile(
#       2     q=[0, 0.01, 0.05, 0.95, 0.99, 1]
#       3 )
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### 正規分布と$2\sigma$範囲による外れ値の確認

# %%
df_chinstrap = df.loc[df.loc[:, "Species_short"] == "Chinstrap", :]

px.histogram(df_chinstrap, x="Body_Mass")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_chinstrap = df.loc[df.loc[:, "Species_short"] == "Chinstrap", :]
#       2
#       3 px.histogram(df_chinstrap, x="Body_Mass")
#
# NameError: name 'df' is not defined

# %%
import scipy.stats as stats

stats.shapiro(df_chinstrap.loc[:, "Body_Mass"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 import scipy.stats as stats
#       2
# ----> 3 stats.shapiro(df_chinstrap.loc[:, "Body_Mass"])
#
# NameError: name 'df_chinstrap' is not defined

# %%
sigma = df_chinstrap.loc[:, "Body_Mass"].std()  # 標準偏差
avg = df_chinstrap.loc[:, "Body_Mass"].mean()
print(f"下限値：{avg - 2 * sigma} 上限値：{avg + 2 * sigma}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sigma = df_chinstrap.loc[:, "Body_Mass"].std()  # 標準偏差
#       2 avg = df_chinstrap.loc[:, "Body_Mass"].mean()
#       3 print(f"下限値：{avg - 2 * sigma} 上限値：{avg + 2 * sigma}")
#
# NameError: name 'df_chinstrap' is not defined

# %%
df_chinstrap.loc[:, "Body_Mass"].quantile(q=[0.025, 0.975])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_chinstrap.loc[:, "Body_Mass"].quantile(q=[0.025, 0.975])
#
# NameError: name 'df_chinstrap' is not defined

# %% [markdown]
# ## 外れ値への対処方法

# %% [markdown]
# ### 上限値と下限値の設定

# %%
df_chinstrap = df_chinstrap.assign(
    Body_Mass_clipped=df_chinstrap.loc[:, "Body_Mass"].clip(
        lower=avg - 2 * sigma,
        upper=avg + 2 * sigma,
    )
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_chinstrap = df_chinstrap.assign(
#       2     Body_Mass_clipped=df_chinstrap.loc[:, "Body_Mass"].clip(
#       3         lower=avg - 2 * sigma,
#       4         upper=avg + 2 * sigma,
#
# NameError: name 'df_chinstrap' is not defined

# %%
px.histogram(
    df_chinstrap.melt(
        id_vars="Individual_ID",
        value_vars=["Body_Mass", "Body_Mass_clipped"],
    ),
    x="value",
    facet_col="variable",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 px.histogram(
#       2     df_chinstrap.melt(
#       3         id_vars="Individual_ID",
#       4         value_vars=["Body_Mass", "Body_Mass_clipped"],
#
# NameError: name 'px' is not defined
