# %% [markdown]
# # データの分布の確認

# %% [markdown]
# ## 統計的な確認

# %%
import pandas as pd

df = pd.read_parquet("data/penguins.parquet")
df.shape  # 行数と列数
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_parquet("data/penguins.parquet")
#       4 df.shape  # 行数と列数
#
# File ~\workspace\musashiuniv\musashiuniv_manuscript\.venv\Lib\site-packages\pandas\io\parquet.py:668, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     508 @set_module("pandas")
#     509 def read_parquet(
#     510     path: FilePath | ReadBuffer[bytes],
#    (...)    518     **kwargs,
#     519 ) -> DataFrame:
#     520     """
#     521     Load a parquet object from the file path, returning a DataFrame.
#     522
#    (...)    665     1    4    9
#     666     """
# --> 668     impl = get_engine(engine)
#     669     check_dtype_backend(dtype_backend)
#     671     return impl.read(
#     672         path,
#     673         columns=columns,
#    (...)    679         **kwargs,
#     680     )
#
# File ~\workspace\musashiuniv\musashiuniv_manuscript\.venv\Lib\site-packages\pandas\io\parquet.py:68, in get_engine(engine)
#      65         except ImportError as err:
#      66             error_msgs += "\n - " + str(err)
# ---> 68     raise ImportError(
#      69         "Unable to find a usable engine; "
#      70         "tried using: 'pyarrow', 'fastparquet'.\n"
#      71         "A suitable version of "
#      72         "pyarrow or fastparquet is required for parquet "
#      73         "support.\n"
#      74         "Trying to import the above resulted in these errors:"
#      75         f"{error_msgs}"
#      76     )
#      78 if engine == "pyarrow":
#      79     return PyArrowImpl()
#
# ImportError: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - `Import pyarrow` failed. pyarrow is required for parquet support. Use pip or conda to install the pyarrow package.
#  - `Import fastparquet` failed. fastparquet is required for parquet support. Use pip or conda to install the fastparquet package.

# %%
df.loc[:, "Sex"].value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.loc[:, "Sex"].value_counts(dropna=False)
#
# NameError: name 'df' is not defined

# %%
df.loc[:, "Sex"].value_counts(ascending=True, dropna=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.loc[:, "Sex"].value_counts(ascending=True, dropna=False)
#
# NameError: name 'df' is not defined

# %%
df.loc[:, "Sex"].value_counts(sort=False, dropna=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.loc[:, "Sex"].value_counts(sort=False, dropna=False)
#
# NameError: name 'df' is not defined

# %%
df.loc[:, "Sex"].value_counts(normalize=True, dropna=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.loc[:, "Sex"].value_counts(normalize=True, dropna=False)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## ヒストグラムによる分布の確認

# %%
import plotly.express as px

px.histogram(df, x="Flipper_Length")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import plotly.express as px
#       2
#       3 px.histogram(df, x="Flipper_Length")
#
# ModuleNotFoundError: No module named 'plotly'

# %%
flipper_ranges = pd.cut(
    df.loc[:, "Flipper_Length"],
    bins=[0, 205, 300],
)
df.groupby(flipper_ranges)["Species_short"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 flipper_ranges = pd.cut(
# ----> 2     df.loc[:, "Flipper_Length"],
#       3     bins=[0, 205, 300],
#       4 )
#       5 df.groupby(flipper_ranges)["Species_short"].value_counts()
#
# NameError: name 'df' is not defined

# %%
px.histogram(
    df,
    x="Flipper_Length",
    color="Species_short",
    color_discrete_sequence=px.colors.qualitative.Dark2,
    pattern_shape="Species_short",
    opacity=0.7,
    barmode="overlay",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 px.histogram(
#       2     df,
#       3     x="Flipper_Length",
#       4     color="Species_short",
#
# NameError: name 'px' is not defined

# %%
px.histogram(df, x="Flipper_Length", nbins=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 px.histogram(df, x="Flipper_Length", nbins=4)
#
# NameError: name 'px' is not defined

# %%
import numpy as np

bin_edges = np.histogram_bin_edges(
    df.loc[:, "Flipper_Length"].dropna(),
    bins="auto",
)
print(len(bin_edges))  # 区間のしきい値の数（両端含む）
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 import numpy as np
#       2
#       3 bin_edges = np.histogram_bin_edges(
# ----> 4     df.loc[:, "Flipper_Length"].dropna(),
#       5     bins="auto",
#       6 )
#       7 print(len(bin_edges))  # 区間のしきい値の数（両端含む）
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 散布図による分布の確認

# %%
px.scatter(
    df,
    x="Culmen_Length",
    y="Flipper_Length",
    color="Species_short",
    color_discrete_sequence=px.colors.qualitative.Dark2,
    symbol="Species_short",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 px.scatter(
#       2     df,
#       3     x="Culmen_Length",
#       4     y="Flipper_Length",
#
# NameError: name 'px' is not defined

# %%
df.groupby("Species_short")[["Culmen_Length", "Flipper_Length"]].corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.groupby("Species_short")[["Culmen_Length", "Flipper_Length"]].corr()
#
# NameError: name 'df' is not defined
