# %% [markdown]
# # 値の重複

# %% [markdown]
# ## 重複の有無の確認方法

# %%
import pandas as pd

df = pd.read_parquet("data/penguins.parquet")
df_adelie = df.loc[df.loc[:, "Species_short"] == "Adelie"]  # Adelieのみ
print(df_adelie.shape)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_parquet("data/penguins.parquet")
#       4 df_adelie = df.loc[df.loc[:, "Species_short"] == "Adelie"]  # Adelieのみ
#       5 print(df_adelie.shape)
#
# File ~\workspace\musashiuniv\musashiuniv_manuscript\.venv\Lib\site-packages\pandas\io\parquet.py:668, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     508 @set_module("pandas")
#     509 def read_parquet(
#     510     path: FilePath | ReadBuffer[bytes],
#    (...)    518     **kwargs,
#     519 ) -> DataFrame:
#     520     """
#     521     Load a parquet object from the file path, returning a DataFrame.
#     522
#    (...)    665     1    4    9
#     666     """
# --> 668     impl = get_engine(engine)
#     669     check_dtype_backend(dtype_backend)
#     671     return impl.read(
#     672         path,
#     673         columns=columns,
#    (...)    679         **kwargs,
#     680     )
#
# File ~\workspace\musashiuniv\musashiuniv_manuscript\.venv\Lib\site-packages\pandas\io\parquet.py:68, in get_engine(engine)
#      65         except ImportError as err:
#      66             error_msgs += "\n - " + str(err)
# ---> 68     raise ImportError(
#      69         "Unable to find a usable engine; "
#      70         "tried using: 'pyarrow', 'fastparquet'.\n"
#      71         "A suitable version of "
#      72         "pyarrow or fastparquet is required for parquet "
#      73         "support.\n"
#      74         "Trying to import the above resulted in these errors:"
#      75         f"{error_msgs}"
#      76     )
#      78 if engine == "pyarrow":
#      79     return PyArrowImpl()
#
# ImportError: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - `Import pyarrow` failed. pyarrow is required for parquet support. Use pip or conda to install the pyarrow package.
#  - `Import fastparquet` failed. fastparquet is required for parquet support. Use pip or conda to install the fastparquet package.

# %%
df_adelie.nunique(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_adelie.nunique(dropna=False)
#
# NameError: name 'df_adelie' is not defined

# %%
# データ全体
df_adelie.duplicated().sum()  # 単に重複の有無を調べる場合はany()メソッド
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # データ全体
# ----> 2 df_adelie.duplicated().sum()  # 単に重複の有無を調べる場合はany()メソッド
#
# NameError: name 'df_adelie' is not defined

# %%
# subsetを指定する例
df_adelie.duplicated(
    subset=[
        "Individual_ID",
    ]
).sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # subsetを指定する例
# ----> 2 df_adelie.duplicated(
#       3     subset=[
#       4         "Individual_ID",
#       5     ]
#
# NameError: name 'df_adelie' is not defined

# %%
# Individual_IDが重複している箇所（すべて、先頭部分）
df_adelie.loc[
    df_adelie.loc[:, "Individual_ID"].duplicated(keep=False)
].sort_values(by="Individual_ID").head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Individual_IDが重複している箇所（すべて、先頭部分）
# ----> 2 df_adelie.loc[
#       3     df_adelie.loc[:, "Individual_ID"].duplicated(keep=False)
#       4 ].sort_values(by="Individual_ID").head()
#
# NameError: name 'df_adelie' is not defined

# %%
# Individual_IDが重複している箇所（最初の出現は含まない）
df_adelie.loc[
    df_adelie.loc[:, "Individual_ID"].duplicated(keep="first")
].sort_values(by="Individual_ID").head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Individual_IDが重複している箇所（最初の出現は含まない）
# ----> 2 df_adelie.loc[
#       3     df_adelie.loc[:, "Individual_ID"].duplicated(keep="first")
#       4 ].sort_values(by="Individual_ID").head()
#
# NameError: name 'df_adelie' is not defined

# %% [markdown]
# ## 重複の発生パターンと対処方法

# %% [markdown]
# ### 行全体の重複への対処

# %%
df_adelie_duplicated = pd.concat(
    [df_adelie, df_adelie]
)  # 重複のあるDataFrameを作成。
print(f"重複あり：{df_adelie_duplicated.shape}")

print(f"重複除去：{df_adelie_duplicated.drop_duplicates().shape}")  # 元と同じ
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 df_adelie_duplicated = pd.concat(
# ----> 2     [df_adelie, df_adelie]
#       3 )  # 重複のあるDataFrameを作成。
#       4 print(f"重複あり：{df_adelie_duplicated.shape}")
#       5
#
# NameError: name 'df_adelie' is not defined

# %% [markdown]
# ### 一部の列の重複への対処

# %%
# 最初の出現を残す
df_adelie.drop_duplicates(
    subset=[
        "Individual_ID",
    ],
    keep="first",
).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # 最初の出現を残す
# ----> 2 df_adelie.drop_duplicates(
#       3     subset=[
#       4         "Individual_ID",
#       5     ],
#
# NameError: name 'df_adelie' is not defined

# %%
# 最後の出現を残す
df_adelie.drop_duplicates(
    subset=[
        "Individual_ID",
    ],
    keep="last",
).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # 最後の出現を残す
# ----> 2 df_adelie.drop_duplicates(
#       3     subset=[
#       4         "Individual_ID",
#       5     ],
#
# NameError: name 'df_adelie' is not defined

# %%
df_adelie.sort_values(by="Date_Egg", ascending=False).drop_duplicates(
    subset="Individual_ID", keep="first"
).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df_adelie.sort_values(by="Date_Egg", ascending=False).drop_duplicates(
#       2     subset="Individual_ID", keep="first"
#       3 ).head()
#
# NameError: name 'df_adelie' is not defined

# %%
# 平均値に集約
df_adelie_agg = df_adelie.groupby("Individual_ID")["Flipper_Length"].mean()
df_adelie_agg.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # 平均値に集約
# ----> 2 df_adelie_agg = df_adelie.groupby("Individual_ID")["Flipper_Length"].mean()
#       3 df_adelie_agg.head()
#
# NameError: name 'df_adelie' is not defined

# %%
df_adelie_agg.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_adelie_agg.shape
#
# NameError: name 'df_adelie_agg' is not defined
