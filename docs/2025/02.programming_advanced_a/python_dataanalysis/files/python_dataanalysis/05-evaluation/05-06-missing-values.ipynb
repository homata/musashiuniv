# %% [markdown]
# # 欠損値

# %% [markdown]
# ## 欠損値の基礎知識
# ### データ型

# %%
import numpy as np
import pandas as pd

rng = np.random.default_rng(1)
float_ser = pd.Series(rng.random(4), index=range(0, 8, 2)).reindex(range(4))
float_ser
# Out:
# 0    0.511822
# 1         NaN
# 2    0.950464
# 3         NaN
# dtype: float64

# %%
dt_ser = pd.Series(
    pd.date_range("2023-01-01", periods=4),
    index=range(0, 8, 2),
).reindex(range(4))
dt_ser
# Out:
# 0   2023-01-01
# 1          NaT
# 2   2023-01-02
# 3          NaT
# dtype: datetime64[ns]

# %%
int_ser = pd.Series(
    rng.integers(0, 10, 4),
    index=range(0, 8, 2),
    dtype=pd.Int64Dtype(),
).reindex(range(4))
int_ser
# Out:
# 0       2
# 1    <NA>
# 2       3
# 3    <NA>
# dtype: Int64

# %%
int_ser.dtype
# Out:
# Int64Dtype()

# %% [markdown]
# ### データの型変換

# %%
# int型
pd.Series([1, None, 3])
# Out:
# 0    1.0
# 1    NaN
# 2    3.0
# dtype: float64

# %%
# bool型
pd.Series([True, None, False])
# Out:
# 0     True
# 1     None
# 2    False
# dtype: object

# %%
# float型
pd.Series([1.0, None, 3.0])
# Out:
# 0    1.0
# 1    NaN
# 2    3.0
# dtype: float64

# %%
# object型
pd.Series(["a", None, "c"])
# Out:
# 0       a
# 1    None
# 2       c
# dtype: object

# %% [markdown]
# ### 欠損値を含むデータの評価

# %%
np.nan == np.nan
# Out:
# False

# %%
np.nan > np.nan
# Out:
# False

# %%
pd.NaT == pd.NaT
# Out:
# False

# %%
pd.NA == pd.NA

# %%
pd.isna(float_ser)
# or
pd.isnull(float_ser)
# or
float_ser.isna()
# or
float_ser.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
int_ser.isna()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
dt_ser.isna()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %% [markdown]
# ### 欠損値を含むデータの演算

# %%
int_ser.sum()
# Out:
# np.int64(5)

# %%
int_ser.cumsum()
# Out:
# 0       2
# 1    <NA>
# 2       5
# 3    <NA>
# dtype: Int64

# %%
int_ser.sum(skipna=False)

# %% [markdown]
# ## 欠損値の発生パターン（メカニズム）と対処方法

# %% [markdown]
# ### 欠損値の確認

# %%
df = pd.read_parquet("data/penguins.parquet")

print(df.isna().sum())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df = pd.read_parquet("data/penguins.parquet")
#       3 print(df.isna().sum())
#
# File D:\workspace\musashiuniv\musashiuniv_manuscript\.venv\Lib\site-packages\pandas\io\parquet.py:653, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     500 @doc(storage_options=_shared_docs["storage_options"])
#     501 def read_parquet(
#     502     path: FilePath | ReadBuffer[bytes],
#    (...)    510     **kwargs,
#     511 ) -> DataFrame:
#     512     """
#     513     Load a parquet object from the file path, returning a DataFrame.
#     514
#    (...)    650     1    4    9
#     651     """
# --> 653     impl = get_engine(engine)
#     655     if use_nullable_dtypes is not lib.no_default:
#     656         msg = (
#     657             "The argument 'use_nullable_dtypes' is deprecated and will be removed "
#     658             "in a future version."
#     659         )
#
# File D:\workspace\musashiuniv\musashiuniv_manuscript\.venv\Lib\site-packages\pandas\io\parquet.py:68, in get_engine(engine)
#      65         except ImportError as err:
#      66             error_msgs += "\n - " + str(err)
# ---> 68     raise ImportError(
#      69         "Unable to find a usable engine; "
#      70         "tried using: 'pyarrow', 'fastparquet'.\n"
#      71         "A suitable version of "
#      72         "pyarrow or fastparquet is required for parquet "
#      73         "support.\n"
#      74         "Trying to import the above resulted in these errors:"
#      75         f"{error_msgs}"
#      76     )
#      78 if engine == "pyarrow":
#      79     return PyArrowImpl()
#
# ImportError: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - Missing optional dependency 'pyarrow'. pyarrow is required for parquet support. Use pip or conda to install pyarrow.
#  - Missing optional dependency 'fastparquet'. fastparquet is required for parquet support. Use pip or conda to install fastparquet.

# %% [markdown]
# ### 欠損値の発生が完全にランダム(MCAR)な場合

# %%
print(df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print(df.shape)
#
# NameError: name 'df' is not defined

# %%
print(df.dropna(subset=["Culmen_Length"]).shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print(df.dropna(subset=["Culmen_Length"]).shape)
#
# NameError: name 'df' is not defined

# %%
print(df.dropna(subset=["Culmen_Length", "Sex"]).shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print(df.dropna(subset=["Culmen_Length", "Sex"]).shape)
#
# NameError: name 'df' is not defined

# %%
print(df.dropna().shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 print(df.dropna().shape)
#
# NameError: name 'df' is not defined

# %%
print(df.dropna(axis=1).shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print(df.dropna(axis=1).shape)
#
# NameError: name 'df' is not defined

# %%
print(
    df.dropna(
        subset=["Culmen_Length", "Sex"],
        how="all",
    ).shape
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 print(
# ----> 2     df.dropna(
#       3         subset=["Culmen_Length", "Sex"],
#       4         how="all",
#       5     ).shape
#       6 )
#
# NameError: name 'df' is not defined

# %%
df.loc[:, "Culmen_Length"].dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.loc[:, "Culmen_Length"].dropna()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### 欠損値の発生が何らかの原因による場合
# #### 単変量補完と多変量補完

# %%
# 種ごとの平均体重の確認
df.groupby("Species_short")["Body_Mass"].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 # 種ごとの平均体重の確認
# ----> 2 df.groupby("Species_short")["Body_Mass"].mean()
#
# NameError: name 'df' is not defined

# %%
# 種ごとの欠損値の件数
df.groupby("Species_short")["Body_Mass"].agg(lambda x: x.isna().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 # 種ごとの欠損値の件数
# ----> 2 df.groupby("Species_short")["Body_Mass"].agg(lambda x: x.isna().sum())
#
# NameError: name 'df' is not defined

# %%
# 種ごとに平均体重で補完
df.groupby("Species_short")["Body_Mass"].transform(
    lambda x: x.fillna(x.mean())
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # 種ごとに平均体重で補完
# ----> 2 df.groupby("Species_short")["Body_Mass"].transform(
#       3     lambda x: x.fillna(x.mean())
#       4 )
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### 行どうしに順序がある場合の補間

# %%
df.loc[:, "Body_Mass"].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.loc[:, "Body_Mass"].head()
#
# NameError: name 'df' is not defined

# %%
df.loc[:, "Body_Mass"].fillna(method="ffill")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df.loc[:, "Body_Mass"].fillna(method="ffill")
#
# NameError: name 'df' is not defined

# %%
df.loc[:, "Body_Mass"].fillna(method="bfill")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df.loc[:, "Body_Mass"].fillna(method="bfill")
#
# NameError: name 'df' is not defined

# %%
df.loc[:, "Body_Mass"].interpolate(method="linear")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df.loc[:, "Body_Mass"].interpolate(method="linear")
#
# NameError: name 'df' is not defined

# %%
# "linear"の場合
pd.Series([1.0, None, 10], index=[1, 10, 100]).interpolate(method="linear")
# Out:
# 1       1.0
# 10      5.5
# 100    10.0
# dtype: float64

# %%
# "index"の場合（"values"も同じ結果）
pd.Series([1.0, None, 10], index=[1, 10, 100]).interpolate(method="index")
# Out:
# 1       1.000000
# 10      1.818182
# 100    10.000000
# dtype: float64

# %%
pd.Series(
    [1.0, None, 10.0],
    index=[
        pd.Timestamp("2023-01-01"),
        pd.Timestamp("2023-01-10"),
        pd.Timestamp("2023-04-10"),
    ],
).interpolate(method="time")
# Out:
# 2023-01-01     1.000000
# 2023-01-10     1.818182
# 2023-04-10    10.000000
# dtype: float64
