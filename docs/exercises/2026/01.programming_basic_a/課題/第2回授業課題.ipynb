# %% [markdown]
# # 第2回授業課題

# %% [markdown]
# １．学籍番号と氏名を○○○○に記入してください
#
# 学籍番号
# ○○○○
#
# 氏名
# ○○○○

# %% [markdown]
# ２. 本日学んだことや取り組んだことを50文字以上で入力してください。（必須）
#
# ○○○○○○○○○○○○○○○○○○○○○○○○

# %% [markdown]
# ３．授業の感想などをご自由にご意見をお書きください。（任意）
#
# ○○○○○○○○○○○○○○○○○○○○○○○○

# %% [markdown]
# ４．下記のPythonのコードで○○の文字を任意の文字に変更して実行してください（必須）

# %%
print("○○")
